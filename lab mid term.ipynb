# %%
import numpy as np
import matplotlib.pyplot as plt
from math import sin
def secant(f,x1,x2,tol,maxiter):
    for i in range(maxiter):
        xnew  = x2 - (x2-x1)/(f(x2)-f(x1))*f(x2)
        if abs(xnew-x2) < tol:
            break
        else:
            x1 = x2
            x2 = xnew
    else:
        print('warning: Maximum number of iterations is reached')
    return xnew, i

f = lambda x: 2*x**2 - 5*x + 3 

x1 = float(input('enter x1: '))
x2 = float(input('enter x2: '))

r, n = secant(f,x1,x2,0.00001,150)

print('Root = %f at %d iterations'%(r,n))
# Out:
# enter x1: 1.5
# enter x2: 1
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14736/3732761833.py in <module>
#      19 x2 = float(input('enter x2: '))
#      20
# ---> 21 r, n = secant(f,x1,x2,0.00001,150)
#      22
#      23 print('Root = %f at %d iterations'%(r,n))
#
# ~\AppData\Local\Temp/ipykernel_14736/3732761833.py in secant(f, x1, x2, tol, maxiter)
#       4 def secant(f,x1,x2,tol,maxiter):
#       5     for i in range(maxiter):
# ----> 6         xnew  = x2 - (x2-x1)/(f(x2)-f(x1))*f(x2)
#       7         if abs(xnew-x2) < tol:
#       8             break
#
# ZeroDivisionError: float division by zero

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import sin
def newton(f,df,x,tol,maxiter):
    for i in range(maxiter):
        xnew = x - f(x)/df(x)
        if abs(xnew-x)<tol:                          
            break
        x = xnew
    else:
        print('warning: Maximum number of iterations is reached')   
    return xnew, i

y = lambda x: 2*x**2 - 5*x + 3 
dy = lambda x : 4*x - 5

x, n = newton(y, dy, 1.45, 0.00001, 50)
print('the root is %.3f at %d iterations.'%(x,n))
# Out:
# the root is 1.500 at 3 iterations.

# %%
import numpy as np
import matplotlib.pyplot as plt
import math as mt

x = np.linspace(1,25,10)
y = 2*x**2 - 5*x + 3
dy = 4*x -5
plt.plot(x,y,dy)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
import numpy as np
import matplotlib.pyplot as plt
f=lambda x: 0.1*x**5 - 0.2*x**3 + 0.1*x - 0.2
x = 0.5
h = 0.1
df1 = -0.01875
df2 = -0.35
print("\t f'(x)\t\t err\t\t f''(x)\t\t err")
dff1 = (f(x+h)-f(x))/h
dff2 = (f(x+2*h)-2*f(x+h)+f(x))/h**2
print("FFD\t% .7f\t% .7f\t% .7f\t% .7f"%(dff1,dff1-df1,dff2,dff2-df2))
dff1 = (f(x)-f(x-h))/h
dff2 = (f(x)-2*f(x-h)+f(x-2*h))/h**2
print("BFD\t% .7f\t% .7f\t% .7f\t% .7f"%(dff1,dff1-df1,dff2,dff2-df2))
dff1 = (f(x+h)-f(x-h))/(2*h)
dff2 = (f(x+h)-2*f(x)+f(x-h))/h**2
print("CFD\t% .7f\t% .7f\t% .7f\t% .7f"%(dff1,dff1-df1,dff2,dff2-df2))
# Out:
# 	 f'(x)		 err		 f''(x)		 err
# FFD	-0.0354900	-0.0167400	-0.2820000	 0.0680000
# BFD	-0.0009900	 0.0177600	-0.3480000	 0.0020000
# CFD	-0.0182400	 0.0005100	-0.3450000	 0.0050000

# %%
import numpy as np
import matplotlib.pyplot as plt
f =lambda x: 0.1*x**5 - 0.2*x**3 +0.1*x-0.2
h=0.1
x= np.linspace(-1,1,10)

#central differences
dff1 = (f(x+h)-f(x-h))/(2*h)
dff2= (f(x+h)-2*f(x)+f(x-h))/h**2

#plot
plt.plot(x,f(x),'*-k',x,dff1,'--b',x,dff2,'-.r')
plt.xlabel('x')
plt.ylabel('y')

plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
f =lambda x: 0.1*x**5 - 0.2*x**3 +0.1*x-0.2
h=0.01

#will create an array of elements between -1 and 1 having 50 equally spaced grid points
x= np.linspace(-1,1,50)

#central differences
dff1 = (f(x+h)-f(x-h))/(2*h)
dff2= (f(x+h)-2*f(x)+f(x-h))/h**2

#plot
plt.plot(x,f(x),'*b',x,dff1,'--r',x,dff2,'-.k')
plt.xlabel('x')
plt.ylabel('y')

plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
f =lambda x: 0.1*x**5 - 0.2*x**3 +0.1*x-0.2
h=0.01

#will create an array of elements between -1 and 1 having 50 equally spaced grid points
x= np.linspace(-1,1,50)

#central differences
dff1 = (f(x+h)-f(x-h))/(2*h)
dff2= (f(x+h)-2*f(x)+f(x-h))/h**2

#plot
plt.plot(x,f(x),'*b',x,dff1,'--r',x,dff2,'-.k')
plt.xlabel('x')
plt.ylabel('y')

plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
f =lambda x: 0.1*x**5 - 0.2*x**3 +0.1*x-0.2
h=0.001

#will create an array of elements between -1 and 1 having 1000 equally spaced grid points
x= np.linspace(-1,1,1000)

#central differences
dff1 = (f(x+h)-f(x-h))/(2*h)
dff2= (f(x+h)-2*f(x)+f(x-h))/h**2

#plot
plt.plot(x,f(x),'.-r',x,dff1,'-*k',x,dff2,'-.b')
plt.xlabel('x')
plt.ylabel('y')

plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
f =lambda x: 0.1*x**5 - 0.2*x**3 +0.1*x-0.2
h=0.1

#will create an array of elements between -1 and 1 having 5 equally spaced grid points
x= np.linspace(-1,1,5)

#backward differences
dff1 = (f(x-f(x)))/(h)
dff2= (f(x)-2*f(x-h)+f(x-h))/h**2

#plot
plt.plot(x,f(x),'-*k',x,dff1,'--b',x,dff2,'-.r')
plt.xlabel('x')
plt.ylabel('y')

plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
f =lambda x: 0.1*x**5 - 0.2*x**3 +0.1*x-0.2
h=0.01

#will create an array of elements between -1 and 1 having 50 equally spaced grid points
x= np.linspace(-1,1,50)

#backward differences
dff1 = (f(x-f(x)))/(h)
dff2= (f(x)-2*f(x-h)+f(x-h))/h**2

#plot
plt.plot(x,f(x),'.-b',x,dff1,'--r',x,dff2,'*-k')
plt.xlabel('x')
plt.ylabel('y')

plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
f =lambda x: 0.1*x**5 - 0.2*x**3 +0.1*x-0.2
h=0.001

#will create an array of elements between -1 and 1 having 5000 equally spaced grid points
x= np.linspace(-1,1,5000)

#backward differences
dff1 = (f(x-f(x)))/(h)
dff2= (f(x)-2*f(x-h)+f(x-h))/h**2

#plot
plt.plot(x,f(x),'-r',x,dff1,'-.k',x,dff2,'*b')
plt.xlabel('x')
plt.ylabel('y')

plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
f =lambda x: 0.1*x**5 - 0.2*x**3 +0.1*x-0.2
h=0.1

x= np.linspace(-1,1,5)

#forward differences
dff1 = (f(x+h)-f(h))/(h)
dff2= (f(x+h)-2*f(x+h)+f(x))/h**2

#plot
plt.plot(x,f(x),'.k',x,dff1,'--b',x,dff2,'-.r')
plt.xlabel('x')
plt.ylabel('y')

plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
f =lambda x: 0.1*x**5 - 0.2*x**3 +0.1*x-0.2
h=0.01

x= np.linspace(-1,1,25)

#forward differences
dff1 = (f(x+h)-f(h))/(h)
dff2= (f(x+h)-2*f(x+h)+f(x))/h**2

#plot
plt.plot(x,f(x),'.r',x,dff1,'*-k',x,dff2,'-.b')
plt.xlabel('x')
plt.ylabel('y')

plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
f =lambda x: 0.1*x**5 - 0.2*x**3 +0.1*x-0.2
h=0.001

x= np.linspace(-1,1,50)

#forward differences
dff1 = (f(x+h)-f(h))/(h)
dff2= (f(x+h)-2*f(x+h)+f(x))/h**2

#plot
plt.plot(x,f(x),'-.b',x,dff1,'*-r',x,dff2,'-.k')
plt.xlabel('x')
plt.ylabel('y')

plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()
